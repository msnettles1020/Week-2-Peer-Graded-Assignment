# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
#  # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Merritt Nettles**

# %% [markdown]
# *I am interested in data science to further support my project teams in my profession. Daily I'm interacting with colleagues who are well versed in data science and I'd like to understand the projects they are completing and how I may use this as well*

# %% [markdown]
# ### Farenheit to Celcius Converter

# %%
C=(90-32)*5/9
print(C)
# Out:
# 32.22222222222222

# %% [markdown]
# - Other conversions (Kelvins to Celcius)
# - Fahrenheit (°F)	Celsius (°C)
#
# - -459.67 °F	-273.15 °C
# - -50 °F	-45.56 °C
# - -40 °F	-40.00 °C
# - -30 °F	-34.44 °C
# - -20 °F	-28.89 °C
# - -10 °F	-23.33 °C
# - 0 °F	-17.78 °C
# - 10 °F	-12.22 °C
# - 20 °F	-6.67 °C
# - 30 °F	-1.11 °C
# - 32 °F	0 °C
# - 40 °F	4.44 °C
# - 50 °F	10.00 °C
# - 60 °F	15.56 °C
# - 70 °F	21.11 °C
# - 80 °F	26.67 °C
# - 90 °F	32.22 °C
# - 100 °F	37.78 °C
# - 110 °F	43.33 °C
# - 120 °F	48.89 °C
# - 130 °F	54.44 °C
# - 140 °F	60.00 °C
# - 150 °F	65.56 °C
# - 160 °F	71.11 °C
# - 170 °F	76.67 °C
# - 180 °F	82.22 °C
# - 190 °F	87.78 °C
# - 200 °F	93.33 °C
# - 212 °F	100 °C
# - 300 °F	148.89 °C
# - 400 °F	204.44 °C
# - 500 °F	260.00 °C
# - 600 °F	315.56 °C
# - 700 °F	371.11 °C
# - 800 °F	426.67 °C
# - 900 °F	482.22 °C
# - 1000 °F	537.78 °C

# %% [markdown]
# ![shutterstock-618369506-996706818.jpg](attachment:f7bcc187-3f26-4246-bcef-83a6c930e363.jpg)

# %% [markdown]
# https://www.metric-conversions.org/temperature/celsius-to-fahrenheit.htm
